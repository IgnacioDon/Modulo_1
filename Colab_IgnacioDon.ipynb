# %% [markdown]
# <a href="https://colab.research.google.com/github/IgnacioDon/Modulo_1/blob/main/Colab_IgnacioDon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Este es mi primer cuaderno
# Aqui voy a mezclar codigo markdown con operaciones matematicas
# *sumar
# *restar
# *multiplicar
# *dividir

# %%
a=3
b=5
a+b
# Out:
# [1] 8

# %%
c=9
d=-1
c-d
# Out:
# [1] 10

# %%
a=1:100
b=a^2
plot(a,b,main="presion gas critico",xlab="volumen",ylab="presion",type="l",col="blue")
# Out:
# Plot with title “presion gas”
